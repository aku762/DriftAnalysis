# %%
#Verify packages by importing them
import os
from dataset import Dataset
from load import load_transcend
from analysis import Analysis
import visual
import numpy as np
import pandas as pd

# %%
# Set environment variables to set the number of threads (Useful for problem solving)
os.environ["OMP_NUM_THREADS"] = "16"  # Limits OpenMP threads
os.environ["OPENBLAS_NUM_THREADS"] = "16"  # Limits threads for OpenBLAS
os.environ["MKL_NUM_THREADS"] = "16"  # Limits threads for Intel MKL
os.environ["NUMEXPR_NUM_THREADS"] = "16"  # Limits NumExpr threads
os.environ["BLAS_NUM_THREADS"] = "16"  # Limits BLAS threads

# %%
# Create dirs to store results
if not os.path.isdir('./pkl_files'):
    os.mkdir('pkl_files')

if not os.path.isdir('./results'):
    os.mkdir('results')

# %%
#Load in Transcend Dataset
PATH = "../Datasets/extended-features/"
X, y, t, f, feature_names, md5 = load_transcend(f"{PATH}extended-features-X-updated.json",
                                                f"{PATH}extended-features-y-updated.json",
                                                f"{PATH}extended-features-meta-updated.json",
                                                f"{PATH}meta_info_file.tsv")
# Out:
# Loading Transcend dataset, this can take up to 3 minutes...
# X loaded
# y loaded
# Timestamps loaded
# Loading family labels
# Family labels loaded
# Reducing feature space...
# Finished loading Transcend dataset

# %%
# Put data in to dataset class
dataset = Dataset(X, y, t, f, feature_names, md5)

# Split dataset and return time aware indexes for training and test
train, test = dataset.time_aware_split_index('month', 6, 1)

# %%
# Run Tsne experiments
Analysis(X, y, t, f, feature_names, md5, train, test).tsne(['Dowgin','Dnotua','Kuguo','Airpush','Revmob'])

# %%
# Train and test for all families
all_families_id = Analysis(X, y, t, f, feature_names, md5, train, test).run(
                training_family=None, testing_family=None,experiment='base', dataset='Transcend') # All families base
all_families_dnotua_id = Analysis(X, y, t, f, feature_names, md5, train, test).run(
                training_family=None, testing_family=None,experiment='base_additional', dataset='Transcend') # All families with dnotua
# Out:
# Trained model with initial training set of length 25143
# Achieved accuracy of 0.976654 and f1 score of 0.903215
# Tested on group 0 with 25143 training samples and 9024 testing samples
# Tested on group 1 with 25143 training samples and 4896 testing samples
# Tested on group 2 with 25143 training samples and 4215 testing samples
# Tested on group 3 with 25143 training samples and 6493 testing samples
# Tested on group 4 with 25143 training samples and 1316 testing samples
# Tested on group 5 with 25143 training samples and 1444 testing samples
# Tested on group 6 with 25143 training samples and 1556 testing samples
# Tested on group 7 with 25143 training samples and 1244 testing samples
# Tested on group 8 with 25143 training samples and 1924 testing samples
# Tested on group 9 with 25143 training samples and 1822 testing samples
# Tested on group 10 with 25143 training samples and 1964 testing samples
# Tested on group 11 with 25143 training samples and 2049 testing samples
# Tested on group 12 with 25143 training samples and 2520 testing samples
# Tested on group 13 with 25143 training samples and 2669 testing samples
# Tested on group 14 with 25143 training samples and 3043 testing samples
# Tested on group 15 with 25143 training samples and 2894 testing samples
# Tested on group 16 with 25143 training samples and 2976 testing samples
# Tested on group 17 with 25143 training samples and 3310 testing samples
# Tested on group 18 with 25143 training samples and 3379 testing samples
# Tested on group 19 with 25143 training samples and 4032 testing samples
# Tested on group 20 with 25143 training samples and 5841 testing samples
# Tested on group 21 with 25143 training samples and 6374 testing samples
# Tested on group 22 with 25143 training samples and 4126 testing samples
# Tested on group 23 with 25143 training samples and 2784 testing samples
# Tested on group 24 with 25143 training samples and 3040 testing samples
# Tested on group 25 with 25143 training samples and 4775 testing samples
# Tested on group 26 with 25143 training samples and 1318 testing samples
# Tested on group 27 with 25143 training samples and 738 testing samples
# Tested on group 28 with 25143 training samples and 194 testing samples
# Tested on group 29 with 25143 training samples and 69 testing samples
# Tested on group 30 with 25143 training samples and 5014 testing samples
# Tested on group 31 with 25143 training samples and 5064 testing samples
# Tested on group 32 with 25143 training samples and 5046 testing samples
# Tested on group 33 with 25143 training samples and 4933 testing samples
# Tested on group 34 with 25143 training samples and 4840 testing samples
# Tested on group 35 with 25143 training samples and 4772 testing samples
# Tested on group 36 with 25143 training samples and 4756 testing samples
# Tested on group 37 with 25143 training samples and 4781 testing samples
# Tested on group 38 with 25143 training samples and 4753 testing samples
# Tested on group 39 with 25143 training samples and 4742 testing samples
# Tested on group 40 with 25143 training samples and 4768 testing samples
# Tested on group 41 with 25143 training samples and 4753 testing samples
# Tested on group 42 with 25143 training samples and 4693 testing samples
# Tested on group 43 with 25143 training samples and 4707 testing samples
# Tested on group 44 with 25143 training samples and 4820 testing samples
# Tested on group 45 with 25143 training samples and 4741 testing samples
# Tested on group 46 with 25143 training samples and 4819 testing samples
# Tested on group 47 with 25143 training samples and 4691 testing samples
# Tested on group 48 with 25143 training samples and 4500 testing samples
# Tested on group 49 with 25143 training samples and 4510 testing samples
# Tested on group 50 with 25143 training samples and 4390 testing samples
# Tested on group 51 with 25143 training samples and 4400 testing samples
# Tested on group 52 with 25143 training samples and 4034 testing samples
# Tested on group 53 with 25143 training samples and 728 testing samples
# Saved result with ID 2
# Done
# Trained model with initial training set of length 26261
# Achieved accuracy of 0.978295 and f1 score of 0.920701
# Tested on group 0 with 26261 training samples and 9024 testing samples
# Tested on group 1 with 26261 training samples and 4896 testing samples
# Tested on group 2 with 26261 training samples and 4215 testing samples
# Tested on group 3 with 26261 training samples and 6493 testing samples
# Tested on group 4 with 26261 training samples and 1316 testing samples
# Tested on group 5 with 26261 training samples and 1444 testing samples
# Tested on group 6 with 26261 training samples and 1556 testing samples
# Tested on group 7 with 26261 training samples and 1244 testing samples
# Tested on group 8 with 26261 training samples and 1924 testing samples
# Tested on group 9 with 26261 training samples and 1822 testing samples
# Tested on group 10 with 26261 training samples and 1964 testing samples
# Tested on group 11 with 26261 training samples and 2049 testing samples
# Tested on group 12 with 26261 training samples and 2520 testing samples
# Tested on group 13 with 26261 training samples and 2669 testing samples
# Tested on group 14 with 26261 training samples and 3043 testing samples
# Tested on group 15 with 26261 training samples and 2894 testing samples
# Tested on group 16 with 26261 training samples and 2976 testing samples
# Tested on group 17 with 26261 training samples and 3310 testing samples
# Tested on group 18 with 26261 training samples and 3379 testing samples
# Tested on group 19 with 26261 training samples and 4032 testing samples
# Tested on group 20 with 26261 training samples and 5841 testing samples
# Tested on group 21 with 26261 training samples and 6374 testing samples
# Tested on group 22 with 26261 training samples and 4126 testing samples
# Tested on group 23 with 26261 training samples and 2784 testing samples
# Tested on group 24 with 26261 training samples and 3040 testing samples
# Tested on group 25 with 26261 training samples and 4775 testing samples
# Tested on group 26 with 26261 training samples and 1318 testing samples
# Tested on group 27 with 26261 training samples and 738 testing samples
# Tested on group 28 with 26261 training samples and 194 testing samples
# Tested on group 29 with 26261 training samples and 69 testing samples
# Tested on group 30 with 26261 training samples and 5014 testing samples
# Tested on group 31 with 26261 training samples and 5064 testing samples
# Tested on group 32 with 26261 training samples and 5046 testing samples
# Tested on group 33 with 26261 training samples and 4933 testing samples
# Tested on group 34 with 26261 training samples and 4840 testing samples
# Tested on group 35 with 26261 training samples and 4772 testing samples
# Tested on group 36 with 26261 training samples and 4756 testing samples
# Tested on group 37 with 26261 training samples and 4781 testing samples
# Tested on group 38 with 26261 training samples and 4753 testing samples
# Tested on group 39 with 26261 training samples and 4742 testing samples
# Tested on group 40 with 26261 training samples and 4768 testing samples
# Tested on group 41 with 26261 training samples and 4753 testing samples
# Tested on group 42 with 26261 training samples and 4693 testing samples
# Tested on group 43 with 26261 training samples and 4707 testing samples
# Tested on group 44 with 26261 training samples and 4820 testing samples
# Tested on group 45 with 26261 training samples and 4741 testing samples
# Tested on group 46 with 26261 training samples and 4819 testing samples
# Tested on group 47 with 26261 training samples and 4691 testing samples
# Tested on group 48 with 26261 training samples and 4500 testing samples
# Tested on group 49 with 26261 training samples and 4510 testing samples
# Tested on group 50 with 26261 training samples and 4390 testing samples
# Tested on group 51 with 26261 training samples and 4400 testing samples
# Tested on group 52 with 26261 training samples and 4034 testing samples
# Tested on group 53 with 26261 training samples and 728 testing samples
# Saved result with ID 3
# Done

# %%
# Select families
training_family = ['Dowgin','Dnotua','Kuguo','Airpush','Revmob']
testing_family = ['Dowgin','Dnotua','Kuguo','Airpush','Revmob']

# Run analysis
cbase_id = Analysis(X, y, t, f, feature_names, md5, train, test).run(
                training_family=training_family, testing_family=testing_family,experiment='half_random', dataset='Transcend') # C base experiment
c1_id = Analysis(X, y, t, f, feature_names, md5, train, test).run(
                training_family=training_family, testing_family=testing_family,experiment='snoop_random', dataset='Transcend') # C 1 experiment
c2_id = Analysis(X, y, t, f, feature_names, md5, train, test).run(
                training_family=training_family, testing_family=testing_family,experiment='nogwsnoop_random', dataset='Transcend') # C 2 experiment
# Out:
# Trained model with initial training set of length 4208
# Achieved accuracy of 0.988356 and f1 score of 0.988331
# Tested on group 0 with 4208 training samples and 745 testing samples
# Tested on group 1 with 4208 training samples and 338 testing samples
# Tested on group 2 with 4208 training samples and 270 testing samples
# Tested on group 3 with 4208 training samples and 390 testing samples
# Tested on group 4 with 4208 training samples and 101 testing samples
# Tested on group 5 with 4208 training samples and 116 testing samples
# Tested on group 6 with 4208 training samples and 130 testing samples
# Tested on group 7 with 4208 training samples and 72 testing samples
# Tested on group 8 with 4208 training samples and 135 testing samples
# Tested on group 9 with 4208 training samples and 70 testing samples
# Tested on group 10 with 4208 training samples and 75 testing samples
# Tested on group 11 with 4208 training samples and 90 testing samples
# Tested on group 12 with 4208 training samples and 110 testing samples
# Tested on group 13 with 4208 training samples and 111 testing samples
# Tested on group 14 with 4208 training samples and 152 testing samples
# Tested on group 15 with 4208 training samples and 138 testing samples
# Tested on group 16 with 4208 training samples and 174 testing samples
# Tested on group 17 with 4208 training samples and 228 testing samples
# Tested on group 18 with 4208 training samples and 210 testing samples
# Tested on group 19 with 4208 training samples and 249 testing samples
# Tested on group 20 with 4208 training samples and 360 testing samples
# Tested on group 21 with 4208 training samples and 267 testing samples
# Tested on group 22 with 4208 training samples and 178 testing samples
# Tested on group 23 with 4208 training samples and 81 testing samples
# Tested on group 24 with 4208 training samples and 84 testing samples
# Tested on group 25 with 4208 training samples and 135 testing samples
# Tested on group 26 with 4208 training samples and 24 testing samples
# Tested on group 27 with 4208 training samples and 15 testing samples
# Tested on group 28 with 4208 training samples and 13 testing samples
# 2024-12-01 17:13:30,812 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 29 with 4208 training samples and 5 testing samples
# Tested on group 30 with 4208 training samples and 126 testing samples
# Tested on group 31 with 4208 training samples and 130 testing samples
# Tested on group 32 with 4208 training samples and 143 testing samples
# Tested on group 33 with 4208 training samples and 107 testing samples
# Tested on group 34 with 4208 training samples and 104 testing samples
# Tested on group 35 with 4208 training samples and 105 testing samples
# Tested on group 36 with 4208 training samples and 115 testing samples
# Tested on group 37 with 4208 training samples and 147 testing samples
# Tested on group 38 with 4208 training samples and 115 testing samples
# Tested on group 39 with 4208 training samples and 119 testing samples
# Tested on group 40 with 4208 training samples and 109 testing samples
# Tested on group 41 with 4208 training samples and 87 testing samples
# Tested on group 42 with 4208 training samples and 75 testing samples
# Tested on group 43 with 4208 training samples and 86 testing samples
# Tested on group 44 with 4208 training samples and 81 testing samples
# Tested on group 45 with 4208 training samples and 58 testing samples
# Tested on group 46 with 4208 training samples and 100 testing samples
# Tested on group 47 with 4208 training samples and 41 testing samples
# Tested on group 48 with 4208 training samples and 59 testing samples
# Tested on group 49 with 4208 training samples and 21 testing samples
# Tested on group 50 with 4208 training samples and 26 testing samples
# Tested on group 51 with 4208 training samples and 82 testing samples
# Tested on group 52 with 4208 training samples and 81 testing samples
# Tested on group 53 with 4208 training samples and 9 testing samples
# Saved result with ID 4
# Done
# Trained model with initial training set of length 4208
# Achieved accuracy of 0.988356 and f1 score of 0.988331
# Snooped on group 0 with 4953 training samples
# Tested on group 0 with 4953 training samples and 745 testing samples
# Snooped on group 1 with 4546 training samples
# Tested on group 1 with 4546 training samples and 338 testing samples
# Snooped on group 2 with 4478 training samples
# Tested on group 2 with 4478 training samples and 270 testing samples
# Snooped on group 3 with 4598 training samples
# Tested on group 3 with 4598 training samples and 390 testing samples
# Snooped on group 4 with 4309 training samples
# Tested on group 4 with 4309 training samples and 101 testing samples
# Snooped on group 5 with 4324 training samples
# Tested on group 5 with 4324 training samples and 116 testing samples
# Snooped on group 6 with 4338 training samples
# Tested on group 6 with 4338 training samples and 130 testing samples
# Snooped on group 7 with 4280 training samples
# Tested on group 7 with 4280 training samples and 72 testing samples
# Snooped on group 8 with 4343 training samples
# Tested on group 8 with 4343 training samples and 135 testing samples
# Snooped on group 9 with 4278 training samples
# Tested on group 9 with 4278 training samples and 70 testing samples
# Snooped on group 10 with 4283 training samples
# Tested on group 10 with 4283 training samples and 75 testing samples
# Snooped on group 11 with 4298 training samples
# Tested on group 11 with 4298 training samples and 90 testing samples
# Snooped on group 12 with 4318 training samples
# Tested on group 12 with 4318 training samples and 110 testing samples
# Snooped on group 13 with 4319 training samples
# Tested on group 13 with 4319 training samples and 111 testing samples
# Snooped on group 14 with 4360 training samples
# Tested on group 14 with 4360 training samples and 152 testing samples
# Snooped on group 15 with 4346 training samples
# Tested on group 15 with 4346 training samples and 138 testing samples
# Snooped on group 16 with 4382 training samples
# Tested on group 16 with 4382 training samples and 174 testing samples
# Snooped on group 17 with 4436 training samples
# Tested on group 17 with 4436 training samples and 228 testing samples
# Snooped on group 18 with 4418 training samples
# Tested on group 18 with 4418 training samples and 210 testing samples
# Snooped on group 19 with 4457 training samples
# Tested on group 19 with 4457 training samples and 249 testing samples
# Snooped on group 20 with 4568 training samples
# Tested on group 20 with 4568 training samples and 360 testing samples
# Snooped on group 21 with 4475 training samples
# Tested on group 21 with 4475 training samples and 267 testing samples
# Snooped on group 22 with 4386 training samples
# Tested on group 22 with 4386 training samples and 178 testing samples
# Snooped on group 23 with 4289 training samples
# Tested on group 23 with 4289 training samples and 81 testing samples
# Snooped on group 24 with 4292 training samples
# Tested on group 24 with 4292 training samples and 84 testing samples
# Snooped on group 25 with 4343 training samples
# Tested on group 25 with 4343 training samples and 135 testing samples
# Snooped on group 26 with 4232 training samples
# Tested on group 26 with 4232 training samples and 24 testing samples
# Snooped on group 27 with 4223 training samples
# Tested on group 27 with 4223 training samples and 15 testing samples
# Snooped on group 28 with 4221 training samples
# Tested on group 28 with 4221 training samples and 13 testing samples
# Snooped on group 29 with 4213 training samples
# 2024-12-01 17:14:36,201 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 29 with 4213 training samples and 5 testing samples
# Snooped on group 30 with 4334 training samples
# Tested on group 30 with 4334 training samples and 126 testing samples
# Snooped on group 31 with 4338 training samples
# Tested on group 31 with 4338 training samples and 130 testing samples
# Snooped on group 32 with 4351 training samples
# Tested on group 32 with 4351 training samples and 143 testing samples
# Snooped on group 33 with 4315 training samples
# Tested on group 33 with 4315 training samples and 107 testing samples
# Snooped on group 34 with 4312 training samples
# Tested on group 34 with 4312 training samples and 104 testing samples
# Snooped on group 35 with 4313 training samples
# Tested on group 35 with 4313 training samples and 105 testing samples
# Snooped on group 36 with 4323 training samples
# Tested on group 36 with 4323 training samples and 115 testing samples
# Snooped on group 37 with 4355 training samples
# Tested on group 37 with 4355 training samples and 147 testing samples
# Snooped on group 38 with 4323 training samples
# Tested on group 38 with 4323 training samples and 115 testing samples
# Snooped on group 39 with 4327 training samples
# Tested on group 39 with 4327 training samples and 119 testing samples
# Snooped on group 40 with 4317 training samples
# Tested on group 40 with 4317 training samples and 109 testing samples
# Snooped on group 41 with 4295 training samples
# Tested on group 41 with 4295 training samples and 87 testing samples
# Snooped on group 42 with 4283 training samples
# Tested on group 42 with 4283 training samples and 75 testing samples
# Snooped on group 43 with 4294 training samples
# Tested on group 43 with 4294 training samples and 86 testing samples
# Snooped on group 44 with 4289 training samples
# Tested on group 44 with 4289 training samples and 81 testing samples
# Snooped on group 45 with 4266 training samples
# Tested on group 45 with 4266 training samples and 58 testing samples
# Snooped on group 46 with 4308 training samples
# Tested on group 46 with 4308 training samples and 100 testing samples
# Snooped on group 47 with 4249 training samples
# Tested on group 47 with 4249 training samples and 41 testing samples
# Snooped on group 48 with 4267 training samples
# Tested on group 48 with 4267 training samples and 59 testing samples
# Snooped on group 49 with 4229 training samples
# Tested on group 49 with 4229 training samples and 21 testing samples
# Snooped on group 50 with 4234 training samples
# Tested on group 50 with 4234 training samples and 26 testing samples
# Snooped on group 51 with 4290 training samples
# Tested on group 51 with 4290 training samples and 82 testing samples
# Snooped on group 52 with 4289 training samples
# Tested on group 52 with 4289 training samples and 81 testing samples
# Snooped on group 53 with 4217 training samples
# 2024-12-01 17:14:57,593 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 53 with 4217 training samples and 9 testing samples
# Saved result with ID 5
# Done
# Trained model with initial training set of length 4208
# Achieved accuracy of 0.988356 and f1 score of 0.988331
# Snooped on group 0 with 4572 training samples
# Tested on group 0 with 4572 training samples and 745 testing samples
# Snooped on group 1 with 4376 training samples
# Tested on group 1 with 4376 training samples and 338 testing samples
# Snooped on group 2 with 4336 training samples
# Tested on group 2 with 4336 training samples and 270 testing samples
# Snooped on group 3 with 4401 training samples
# Tested on group 3 with 4401 training samples and 390 testing samples
# Snooped on group 4 with 4260 training samples
# Tested on group 4 with 4260 training samples and 101 testing samples
# Snooped on group 5 with 4263 training samples
# Tested on group 5 with 4263 training samples and 116 testing samples
# Snooped on group 6 with 4272 training samples
# Tested on group 6 with 4272 training samples and 130 testing samples
# Snooped on group 7 with 4244 training samples
# Tested on group 7 with 4244 training samples and 72 testing samples
# Snooped on group 8 with 4275 training samples
# Tested on group 8 with 4275 training samples and 135 testing samples
# Snooped on group 9 with 4244 training samples
# Tested on group 9 with 4244 training samples and 70 testing samples
# Snooped on group 10 with 4243 training samples
# Tested on group 10 with 4243 training samples and 75 testing samples
# Snooped on group 11 with 4246 training samples
# Tested on group 11 with 4246 training samples and 90 testing samples
# Snooped on group 12 with 4261 training samples
# Tested on group 12 with 4261 training samples and 110 testing samples
# Snooped on group 13 with 4262 training samples
# Tested on group 13 with 4262 training samples and 111 testing samples
# Snooped on group 14 with 4277 training samples
# Tested on group 14 with 4277 training samples and 152 testing samples
# Snooped on group 15 with 4277 training samples
# Tested on group 15 with 4277 training samples and 138 testing samples
# Snooped on group 16 with 4295 training samples
# Tested on group 16 with 4295 training samples and 174 testing samples
# Snooped on group 17 with 4318 training samples
# Tested on group 17 with 4318 training samples and 228 testing samples
# Snooped on group 18 with 4310 training samples
# Tested on group 18 with 4310 training samples and 210 testing samples
# Snooped on group 19 with 4327 training samples
# Tested on group 19 with 4327 training samples and 249 testing samples
# Snooped on group 20 with 4385 training samples
# Tested on group 20 with 4385 training samples and 360 testing samples
# Snooped on group 21 with 4334 training samples
# Tested on group 21 with 4334 training samples and 267 testing samples
# Snooped on group 22 with 4296 training samples
# Tested on group 22 with 4296 training samples and 178 testing samples
# Snooped on group 23 with 4246 training samples
# Tested on group 23 with 4246 training samples and 81 testing samples
# Snooped on group 24 with 4246 training samples
# Tested on group 24 with 4246 training samples and 84 testing samples
# Snooped on group 25 with 4275 training samples
# Tested on group 25 with 4275 training samples and 135 testing samples
# Snooped on group 26 with 4221 training samples
# Tested on group 26 with 4221 training samples and 24 testing samples
# Snooped on group 27 with 4215 training samples
# Tested on group 27 with 4215 training samples and 15 testing samples
# Snooped on group 28 with 4217 training samples
# Tested on group 28 with 4217 training samples and 13 testing samples
# Snooped on group 29 with 4210 training samples
# 2024-12-01 17:15:52,717 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 29 with 4210 training samples and 5 testing samples
# Snooped on group 30 with 4270 training samples
# Tested on group 30 with 4270 training samples and 126 testing samples
# Snooped on group 31 with 4272 training samples
# Tested on group 31 with 4272 training samples and 130 testing samples
# Snooped on group 32 with 4275 training samples
# Tested on group 32 with 4275 training samples and 143 testing samples
# Snooped on group 33 with 4262 training samples
# Tested on group 33 with 4262 training samples and 107 testing samples
# Snooped on group 34 with 4258 training samples
# Tested on group 34 with 4258 training samples and 104 testing samples
# Snooped on group 35 with 4259 training samples
# Tested on group 35 with 4259 training samples and 105 testing samples
# Snooped on group 36 with 4263 training samples
# Tested on group 36 with 4263 training samples and 115 testing samples
# Snooped on group 37 with 4278 training samples
# Tested on group 37 with 4278 training samples and 147 testing samples
# Snooped on group 38 with 4263 training samples
# Tested on group 38 with 4263 training samples and 115 testing samples
# Snooped on group 39 with 4265 training samples
# Tested on group 39 with 4265 training samples and 119 testing samples
# Snooped on group 40 with 4261 training samples
# Tested on group 40 with 4261 training samples and 109 testing samples
# Snooped on group 41 with 4246 training samples
# Tested on group 41 with 4246 training samples and 87 testing samples
# Snooped on group 42 with 4243 training samples
# Tested on group 42 with 4243 training samples and 75 testing samples
# Snooped on group 43 with 4245 training samples
# Tested on group 43 with 4245 training samples and 86 testing samples
# Snooped on group 44 with 4246 training samples
# Tested on group 44 with 4246 training samples and 81 testing samples
# Snooped on group 45 with 4237 training samples
# Tested on group 45 with 4237 training samples and 58 testing samples
# Snooped on group 46 with 4260 training samples
# Tested on group 46 with 4260 training samples and 100 testing samples
# Snooped on group 47 with 4231 training samples
# Tested on group 47 with 4231 training samples and 41 testing samples
# Snooped on group 48 with 4238 training samples
# Tested on group 48 with 4238 training samples and 59 testing samples
# Snooped on group 49 with 4220 training samples
# Tested on group 49 with 4220 training samples and 21 testing samples
# Snooped on group 50 with 4221 training samples
# Tested on group 50 with 4221 training samples and 26 testing samples
# Snooped on group 51 with 4246 training samples
# Tested on group 51 with 4246 training samples and 82 testing samples
# Snooped on group 52 with 4246 training samples
# Tested on group 52 with 4246 training samples and 81 testing samples
# Snooped on group 53 with 4212 training samples
# Tested on group 53 with 4212 training samples and 9 testing samples
# Saved result with ID 6
# Done

# %%
# Loops for solo training
loop_id = []
for train_fam in training_family:
    if train_fam == 'Dnotua':
        experiment_t = 'base_additional'
    else:
        experiment_t = 'base'
    id = Analysis(X, y, t, f, feature_names, md5, train, test).run(
                training_family=[train_fam], testing_family=testing_family,experiment=experiment_t, dataset='Transcend') # Solo family experiments
    loop_id.append(id)
# Out:
# Trained model with initial training set of length 2760
# Achieved accuracy of 0.988406 and f1 score of 0.988364
# Tested on group 0 with 2760 training samples and 1490 testing samples
# Tested on group 1 with 2760 training samples and 676 testing samples
# Tested on group 2 with 2760 training samples and 540 testing samples
# Tested on group 3 with 2760 training samples and 780 testing samples
# Tested on group 4 with 2760 training samples and 202 testing samples
# Tested on group 5 with 2760 training samples and 232 testing samples
# Tested on group 6 with 2760 training samples and 260 testing samples
# Tested on group 7 with 2760 training samples and 144 testing samples
# Tested on group 8 with 2760 training samples and 270 testing samples
# Tested on group 9 with 2760 training samples and 140 testing samples
# Tested on group 10 with 2760 training samples and 150 testing samples
# Tested on group 11 with 2760 training samples and 180 testing samples
# Tested on group 12 with 2760 training samples and 220 testing samples
# Tested on group 13 with 2760 training samples and 222 testing samples
# Tested on group 14 with 2760 training samples and 304 testing samples
# Tested on group 15 with 2760 training samples and 276 testing samples
# Tested on group 16 with 2760 training samples and 348 testing samples
# Tested on group 17 with 2760 training samples and 456 testing samples
# Tested on group 18 with 2760 training samples and 420 testing samples
# Tested on group 19 with 2760 training samples and 498 testing samples
# Tested on group 20 with 2760 training samples and 720 testing samples
# Tested on group 21 with 2760 training samples and 534 testing samples
# Tested on group 22 with 2760 training samples and 356 testing samples
# Tested on group 23 with 2760 training samples and 162 testing samples
# Tested on group 24 with 2760 training samples and 168 testing samples
# Tested on group 25 with 2760 training samples and 270 testing samples
# Tested on group 26 with 2760 training samples and 48 testing samples
# 2024-12-01 17:17:42,123 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 27 with 2760 training samples and 30 testing samples
# Tested on group 28 with 2760 training samples and 26 testing samples
# 2024-12-01 17:17:42,388 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 29 with 2760 training samples and 10 testing samples
# Tested on group 30 with 2760 training samples and 252 testing samples
# Tested on group 31 with 2760 training samples and 260 testing samples
# Tested on group 32 with 2760 training samples and 286 testing samples
# Tested on group 33 with 2760 training samples and 214 testing samples
# Tested on group 34 with 2760 training samples and 208 testing samples
# 2024-12-01 17:17:47,835 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 35 with 2760 training samples and 210 testing samples
# Tested on group 36 with 2760 training samples and 230 testing samples
# Tested on group 37 with 2760 training samples and 294 testing samples
# Tested on group 38 with 2760 training samples and 230 testing samples
# Tested on group 39 with 2760 training samples and 238 testing samples
# Tested on group 40 with 2760 training samples and 218 testing samples
# Tested on group 41 with 2760 training samples and 174 testing samples
# Tested on group 42 with 2760 training samples and 150 testing samples
# Tested on group 43 with 2760 training samples and 172 testing samples
# Tested on group 44 with 2760 training samples and 162 testing samples
# Tested on group 45 with 2760 training samples and 116 testing samples
# Tested on group 46 with 2760 training samples and 200 testing samples
# Tested on group 47 with 2760 training samples and 82 testing samples
# Tested on group 48 with 2760 training samples and 118 testing samples
# Tested on group 49 with 2760 training samples and 42 testing samples
# Tested on group 50 with 2760 training samples and 52 testing samples
# Tested on group 51 with 2760 training samples and 164 testing samples
# Tested on group 52 with 2760 training samples and 162 testing samples
# Tested on group 53 with 2760 training samples and 18 testing samples
# Saved result with ID 7
# Done
# Trained model with initial training set of length 1150
# Achieved accuracy of 0.989565 and f1 score of 0.989655
# Tested on group 0 with 1150 training samples and 1490 testing samples
# Tested on group 1 with 1150 training samples and 676 testing samples
# Tested on group 2 with 1150 training samples and 540 testing samples
# Tested on group 3 with 1150 training samples and 780 testing samples
# Tested on group 4 with 1150 training samples and 202 testing samples
# Tested on group 5 with 1150 training samples and 232 testing samples
# Tested on group 6 with 1150 training samples and 260 testing samples
# Tested on group 7 with 1150 training samples and 144 testing samples
# Tested on group 8 with 1150 training samples and 270 testing samples
# Tested on group 9 with 1150 training samples and 140 testing samples
# Tested on group 10 with 1150 training samples and 150 testing samples
# Tested on group 11 with 1150 training samples and 180 testing samples
# Tested on group 12 with 1150 training samples and 220 testing samples
# Tested on group 13 with 1150 training samples and 222 testing samples
# Tested on group 14 with 1150 training samples and 304 testing samples
# Tested on group 15 with 1150 training samples and 276 testing samples
# Tested on group 16 with 1150 training samples and 348 testing samples
# Tested on group 17 with 1150 training samples and 456 testing samples
# Tested on group 18 with 1150 training samples and 420 testing samples
# Tested on group 19 with 1150 training samples and 498 testing samples
# Tested on group 20 with 1150 training samples and 720 testing samples
# Tested on group 21 with 1150 training samples and 534 testing samples
# Tested on group 22 with 1150 training samples and 356 testing samples
# Tested on group 23 with 1150 training samples and 162 testing samples
# Tested on group 24 with 1150 training samples and 168 testing samples
# Tested on group 25 with 1150 training samples and 270 testing samples
# Tested on group 26 with 1150 training samples and 48 testing samples
# Tested on group 27 with 1150 training samples and 30 testing samples
# Tested on group 28 with 1150 training samples and 26 testing samples
# Tested on group 29 with 1150 training samples and 10 testing samples
# Tested on group 30 with 1150 training samples and 252 testing samples
# Tested on group 31 with 1150 training samples and 260 testing samples
# Tested on group 32 with 1150 training samples and 286 testing samples
# Tested on group 33 with 1150 training samples and 214 testing samples
# Tested on group 34 with 1150 training samples and 208 testing samples
# Tested on group 35 with 1150 training samples and 210 testing samples
# Tested on group 36 with 1150 training samples and 230 testing samples
# Tested on group 37 with 1150 training samples and 294 testing samples
# Tested on group 38 with 1150 training samples and 230 testing samples
# Tested on group 39 with 1150 training samples and 238 testing samples
# Tested on group 40 with 1150 training samples and 218 testing samples
# Tested on group 41 with 1150 training samples and 174 testing samples
# Tested on group 42 with 1150 training samples and 150 testing samples
# Tested on group 43 with 1150 training samples and 172 testing samples
# Tested on group 44 with 1150 training samples and 162 testing samples
# Tested on group 45 with 1150 training samples and 116 testing samples
# Tested on group 46 with 1150 training samples and 200 testing samples
# Tested on group 47 with 1150 training samples and 82 testing samples
# Tested on group 48 with 1150 training samples and 118 testing samples
# Tested on group 49 with 1150 training samples and 42 testing samples
# Tested on group 50 with 1150 training samples and 52 testing samples
# Tested on group 51 with 1150 training samples and 164 testing samples
# Tested on group 52 with 1150 training samples and 162 testing samples
# Tested on group 53 with 1150 training samples and 18 testing samples
# Saved result with ID 8
# Done
# Trained model with initial training set of length 322
# Achieved accuracy of 0.990683 and f1 score of 0.990654
# Tested on group 0 with 322 training samples and 1490 testing samples
# Tested on group 1 with 322 training samples and 676 testing samples
# Tested on group 2 with 322 training samples and 540 testing samples
# Tested on group 3 with 322 training samples and 780 testing samples
# Tested on group 4 with 322 training samples and 202 testing samples
# Tested on group 5 with 322 training samples and 232 testing samples
# Tested on group 6 with 322 training samples and 260 testing samples
# Tested on group 7 with 322 training samples and 144 testing samples
# Tested on group 8 with 322 training samples and 270 testing samples
# Tested on group 9 with 322 training samples and 140 testing samples
# Tested on group 10 with 322 training samples and 150 testing samples
# Tested on group 11 with 322 training samples and 180 testing samples
# Tested on group 12 with 322 training samples and 220 testing samples
# Tested on group 13 with 322 training samples and 222 testing samples
# Tested on group 14 with 322 training samples and 304 testing samples
# Tested on group 15 with 322 training samples and 276 testing samples
# Tested on group 16 with 322 training samples and 348 testing samples
# Tested on group 17 with 322 training samples and 456 testing samples
# Tested on group 18 with 322 training samples and 420 testing samples
# Tested on group 19 with 322 training samples and 498 testing samples
# Tested on group 20 with 322 training samples and 720 testing samples
# Tested on group 21 with 322 training samples and 534 testing samples
# Tested on group 22 with 322 training samples and 356 testing samples
# Tested on group 23 with 322 training samples and 162 testing samples
# Tested on group 24 with 322 training samples and 168 testing samples
# Tested on group 25 with 322 training samples and 270 testing samples
# Tested on group 26 with 322 training samples and 48 testing samples
# 2024-12-01 17:20:01,657 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 27 with 322 training samples and 30 testing samples
# Tested on group 28 with 322 training samples and 26 testing samples
# Tested on group 29 with 322 training samples and 10 testing samples
# Tested on group 30 with 322 training samples and 252 testing samples
# Tested on group 31 with 322 training samples and 260 testing samples
# Tested on group 32 with 322 training samples and 286 testing samples
# Tested on group 33 with 322 training samples and 214 testing samples
# Tested on group 34 with 322 training samples and 208 testing samples
# Tested on group 35 with 322 training samples and 210 testing samples
# Tested on group 36 with 322 training samples and 230 testing samples
# Tested on group 37 with 322 training samples and 294 testing samples
# Tested on group 38 with 322 training samples and 230 testing samples
# Tested on group 39 with 322 training samples and 238 testing samples
# Tested on group 40 with 322 training samples and 218 testing samples
# Tested on group 41 with 322 training samples and 174 testing samples
# Tested on group 42 with 322 training samples and 150 testing samples
# Tested on group 43 with 322 training samples and 172 testing samples
# Tested on group 44 with 322 training samples and 162 testing samples
# Tested on group 45 with 322 training samples and 116 testing samples
# Tested on group 46 with 322 training samples and 200 testing samples
# Tested on group 47 with 322 training samples and 82 testing samples
# Tested on group 48 with 322 training samples and 118 testing samples
# Tested on group 49 with 322 training samples and 42 testing samples
# Tested on group 50 with 322 training samples and 52 testing samples
# Tested on group 51 with 322 training samples and 164 testing samples
# Tested on group 52 with 322 training samples and 162 testing samples
# Tested on group 53 with 322 training samples and 18 testing samples
# Saved result with ID 9
# Done
# Trained model with initial training set of length 536
# Achieved accuracy of 0.990672 and f1 score of 0.990654
# Tested on group 0 with 536 training samples and 1490 testing samples
# Tested on group 1 with 536 training samples and 676 testing samples
# Tested on group 2 with 536 training samples and 540 testing samples
# Tested on group 3 with 536 training samples and 780 testing samples
# Tested on group 4 with 536 training samples and 202 testing samples
# Tested on group 5 with 536 training samples and 232 testing samples
# Tested on group 6 with 536 training samples and 260 testing samples
# Tested on group 7 with 536 training samples and 144 testing samples
# Tested on group 8 with 536 training samples and 270 testing samples
# Tested on group 9 with 536 training samples and 140 testing samples
# Tested on group 10 with 536 training samples and 150 testing samples
# Tested on group 11 with 536 training samples and 180 testing samples
# Tested on group 12 with 536 training samples and 220 testing samples
# Tested on group 13 with 536 training samples and 222 testing samples
# Tested on group 14 with 536 training samples and 304 testing samples
# Tested on group 15 with 536 training samples and 276 testing samples
# Tested on group 16 with 536 training samples and 348 testing samples
# Tested on group 17 with 536 training samples and 456 testing samples
# Tested on group 18 with 536 training samples and 420 testing samples
# Tested on group 19 with 536 training samples and 498 testing samples
# Tested on group 20 with 536 training samples and 720 testing samples
# Tested on group 21 with 536 training samples and 534 testing samples
# Tested on group 22 with 536 training samples and 356 testing samples
# Tested on group 23 with 536 training samples and 162 testing samples
# Tested on group 24 with 536 training samples and 168 testing samples
# Tested on group 25 with 536 training samples and 270 testing samples
# Tested on group 26 with 536 training samples and 48 testing samples
# Tested on group 27 with 536 training samples and 30 testing samples
# Tested on group 28 with 536 training samples and 26 testing samples
# 2024-12-01 17:21:11,419 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 29 with 536 training samples and 10 testing samples
# Tested on group 30 with 536 training samples and 252 testing samples
# Tested on group 31 with 536 training samples and 260 testing samples
# Tested on group 32 with 536 training samples and 286 testing samples
# Tested on group 33 with 536 training samples and 214 testing samples
# Tested on group 34 with 536 training samples and 208 testing samples
# 2024-12-01 17:21:17,141 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 35 with 536 training samples and 210 testing samples
# Tested on group 36 with 536 training samples and 230 testing samples
# Tested on group 37 with 536 training samples and 294 testing samples
# Tested on group 38 with 536 training samples and 230 testing samples
# Tested on group 39 with 536 training samples and 238 testing samples
# Tested on group 40 with 536 training samples and 218 testing samples
# Tested on group 41 with 536 training samples and 174 testing samples
# Tested on group 42 with 536 training samples and 150 testing samples
# Tested on group 43 with 536 training samples and 172 testing samples
# Tested on group 44 with 536 training samples and 162 testing samples
# Tested on group 45 with 536 training samples and 116 testing samples
# Tested on group 46 with 536 training samples and 200 testing samples
# 2024-12-01 17:21:28,329 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 47 with 536 training samples and 82 testing samples
# 2024-12-01 17:21:28,722 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 48 with 536 training samples and 118 testing samples
# 2024-12-01 17:21:29,274 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 49 with 536 training samples and 42 testing samples
# Tested on group 50 with 536 training samples and 52 testing samples
# Tested on group 51 with 536 training samples and 164 testing samples
# Tested on group 52 with 536 training samples and 162 testing samples
# Tested on group 53 with 536 training samples and 18 testing samples
# Saved result with ID 10
# Done
# Trained model with initial training set of length 560
# Achieved accuracy of 1.000000 and f1 score of 1.000000
# Tested on group 0 with 560 training samples and 1490 testing samples
# Tested on group 1 with 560 training samples and 676 testing samples
# Tested on group 2 with 560 training samples and 540 testing samples
# Tested on group 3 with 560 training samples and 780 testing samples
# Tested on group 4 with 560 training samples and 202 testing samples
# Tested on group 5 with 560 training samples and 232 testing samples
# Tested on group 6 with 560 training samples and 260 testing samples
# Tested on group 7 with 560 training samples and 144 testing samples
# Tested on group 8 with 560 training samples and 270 testing samples
# Tested on group 9 with 560 training samples and 140 testing samples
# Tested on group 10 with 560 training samples and 150 testing samples
# Tested on group 11 with 560 training samples and 180 testing samples
# Tested on group 12 with 560 training samples and 220 testing samples
# Tested on group 13 with 560 training samples and 222 testing samples
# Tested on group 14 with 560 training samples and 304 testing samples
# Tested on group 15 with 560 training samples and 276 testing samples
# Tested on group 16 with 560 training samples and 348 testing samples
# Tested on group 17 with 560 training samples and 456 testing samples
# Tested on group 18 with 560 training samples and 420 testing samples
# Tested on group 19 with 560 training samples and 498 testing samples
# Tested on group 20 with 560 training samples and 720 testing samples
# Tested on group 21 with 560 training samples and 534 testing samples
# Tested on group 22 with 560 training samples and 356 testing samples
# Tested on group 23 with 560 training samples and 162 testing samples
# Tested on group 24 with 560 training samples and 168 testing samples
# Tested on group 25 with 560 training samples and 270 testing samples
# 2024-12-01 17:22:20,547 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 26 with 560 training samples and 48 testing samples
# Tested on group 27 with 560 training samples and 30 testing samples
# Tested on group 28 with 560 training samples and 26 testing samples
# 2024-12-01 17:22:21,056 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 29 with 560 training samples and 10 testing samples
# Tested on group 30 with 560 training samples and 252 testing samples
# Tested on group 31 with 560 training samples and 260 testing samples
# Tested on group 32 with 560 training samples and 286 testing samples
# Tested on group 33 with 560 training samples and 214 testing samples
# Tested on group 34 with 560 training samples and 208 testing samples
# Tested on group 35 with 560 training samples and 210 testing samples
# Tested on group 36 with 560 training samples and 230 testing samples
# Tested on group 37 with 560 training samples and 294 testing samples
# Tested on group 38 with 560 training samples and 230 testing samples
# Tested on group 39 with 560 training samples and 238 testing samples
# Tested on group 40 with 560 training samples and 218 testing samples
# Tested on group 41 with 560 training samples and 174 testing samples
# Tested on group 42 with 560 training samples and 150 testing samples
# Tested on group 43 with 560 training samples and 172 testing samples
# Tested on group 44 with 560 training samples and 162 testing samples
# Tested on group 45 with 560 training samples and 116 testing samples
# Tested on group 46 with 560 training samples and 200 testing samples
# 2024-12-01 17:22:38,020 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 47 with 560 training samples and 82 testing samples
# Tested on group 48 with 560 training samples and 118 testing samples
# 2024-12-01 17:22:38,971 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 49 with 560 training samples and 42 testing samples
# 2024-12-01 17:22:39,178 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 50 with 560 training samples and 52 testing samples
# Tested on group 51 with 560 training samples and 164 testing samples
# 2024-12-01 17:22:40,232 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 52 with 560 training samples and 162 testing samples
# 2024-12-01 17:22:40,988 - py.warnings - WARNING - C:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#
# Tested on group 53 with 560 training samples and 18 testing samples
# Saved result with ID 11
# Done

# %%
# Write IDs in file for future reference
with open("results/results_files_id",'w') as f:
    f.writelines(f"all_families_id: {all_families_id}")
    f.writelines(f"all_families_dnotua_id: {all_families_dnotua_id}")
    f.writelines(f"cbase_id: {cbase_id}")
    f.writelines(f"c1_id: {c1_id}")
    f.writelines(f"c2_id: {c2_id}")
    f.writelines(f"dowgin_solo_id: {loop_id[0]}")
    f.writelines(f"dnotua_solo_id: {loop_id[1]}")
    f.writelines(f"kuguo_solo_id: {loop_id[2]}")
    f.writelines(f"airpush_solo_id: {loop_id[3]}")
    f.writelines(f"revmob_solo_id: {loop_id[4]}")

# %%
# Load in files
all_families = visual.ResultsLoader().load_file_from_id(all_families_id)
all_families_dnotua = visual.ResultsLoader().load_file_from_id(all_families_dnotua_id)
cbase = visual.ResultsLoader().load_file_from_id(cbase_id)
c1 = visual.ResultsLoader().load_file_from_id(c1_id)
c2 = visual.ResultsLoader().load_file_from_id(c2_id)
dowgin_solo = visual.ResultsLoader().load_file_from_id(loop_id[0])
dnotua_solo = visual.ResultsLoader().load_file_from_id(loop_id[1])
kuguo_solo = visual.ResultsLoader().load_file_from_id(loop_id[2])
airpush_solo = visual.ResultsLoader().load_file_from_id(loop_id[3])
revmob_solo = visual.ResultsLoader().load_file_from_id(loop_id[4])

# %%
# Add LaTeX to PATH explicitly
os.environ["PATH"] += os.pathsep + r"C:\Users\Anthony\AppData\Local\Programs\MiKTeX\miktex\bin\x64"

# Print out the PATH to verify it has been added
print(os.environ["PATH"])
# Out:
# c:\Users\Anthony\AppData\Local\Microsoft\WindowsApps;c:\Users\Anthony\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0\;C:\Windows\System32\OpenSSH\;C:\Program Files\Git\cmd;C:\ProgramData\chocolatey\bin;C:\Users\Anthony\AppData\Local\Microsoft\WindowsApps;C:\Users\Anthony\AppData\Local\Programs\Microsoft VS Code\bin;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0\;C:\Windows\System32\OpenSSH\;C:\Program Files\Git\cmd;C:\ProgramData\chocolatey\bin;C:\Users\Anthony\AppData\Local\Microsoft\WindowsApps;C:\Users\Anthony\AppData\Local\Programs\Microsoft VS Code\bin;C:\Users\Anthony\AppData\Local\Programs\MiKTeX\miktex\bin;C:\Users\Anthony\AppData\Local\Programs\MiKTeX\miktex\bin;C:\Users\Anthony\AppData\Local\Programs\MiKTeX\miktex\bin;C:\Users\Anthony\AppData\Local\Programs\MiKTeX\miktex\bin\x64

# %%
# Plot files and save in output folder
visual.Viz(all_families).plot_single('performance', fname='transcend_all.pdf') # Fig 2a
visual.Viz(all_families).plot_single('distribution', fname='transcend_distribution_all.pdf') # Fig 2b
visual.Viz(c2, c1, label1='(C1)', label2='(C2)').plot_performance_distribution(fname='goodware_snoop_performance.pdf') # Fig 3
visual.VizExpl(cbase,c1).mean_of_weights_of_top_feature_of_missed_family_samples(['DNOTUA'], missed=True) # Table 1
visual.VizExpl(cbase,c1).mean_of_weights_of_top_feature_of_missed_family_samples(['AIRPUSH'], missed=True) # Table 3
visual.Viz(c2, c1, label1='(C2)', label2='(C1)').plot_single('difference', month_selection=[23, 31, 47], fname='goodware_snoop_diff_crop.pdf') # Figure 4a
visual.Viz(cbase, c1, label1='(Cbase)', label2='(C1)').plot_single('difference', month_selection=[25, 31, 52], fname='malware_snoop_diff_crop.pdf') # Figure 4b
visual.Viz(cbase, c1, label1='(Cbase)', label2='(C1)').plot_performance_distribution(fname='malware_snoop_performance.pdf') # Figure 5
visual.Viz(all_families_dnotua).plot_single('performance', fname='transcend_all_dnotua.pdf') # Figure 6
visual.FamilyIso(dowgin_solo,dnotua_solo,kuguo_solo,airpush_solo,revmob_solo).plot_family_iso_matrix(fname='solo_performance_grid.pdf')# Figure 7 & Table 4
visual.DimensionReduction().tsne_visual(['DOWGIN','DNOTUA','KUGUO','AIRPUSH','REVMOB'], fname='tsne_malware_overtime.pdf')
visual.VizExpl(c1).top_features_of_given_family([1,52,31,25,47,33,27,36,22,17,53,44,37],['DNOTUA']) # Table 5
visual.VizExpl(c1).top_features_of_given_family([1,52,31,25,47,33,27,36,22,17,53,44,37],['KUGUO']) # Table 6
# Out:
# transcend_all.pdf
# results\transcend_all.pdf
# transcend_distribution_all.pdf
# results\transcend_distribution_all.pdf
# [22 30 46 43 36 51 24 28 37 26 13 20]
# results\goodware_snoop_performance.pdf
# Top 5 features of C2 and their value changes from C1 to C2
# ----------
# urls::https://www_googletagmanager_com 0.692 41.65 6022.226%
# api_calls::android/content/Context;->startService 0.613 33.972 5545.382%
# intents::android_intent_category_LAUNCHER 13.307 3.612 27.145%
# interesting_calls::Cipher(DES) 2.431 2.334 96.033%
# app_permissions::name='com_android_launcher_permission_INSTALL_SHORTCUT' 1.273 1.364 107.191%
# Top 5 features of C2 and their value changes from C1 to C2
# ----------
# urls::https://market_android_com 0.956 86.399 9038.947%
# urls::https://www_googletagmanager_com 0.785 21.608 2751.322%
# urls::https://play_google_com/store/ 12.84 14.161 110.287%
# intents::android_intent_action_PACKAGE_ADDED 12.805 12.367 96.577%
# urls::http://play_google_com/store/ 12.84 11.343 88.337%
# goodware_snoop_diff_crop.pdf
# results\goodware_snoop_diff_crop.pdf
# malware_snoop_diff_crop.pdf
# results\malware_snoop_diff_crop.pdf
# [51 30 24 46 32 26 35 21 16 52 43 37]
# results\malware_snoop_performance.pdf
# transcend_all_dnotua.pdf
# results\transcend_all_dnotua.pdf
# 2024-12-01 17:45:28,200 - py.warnings - WARNING - c:\Users\Anthony\OneDrive - University of Luxembourg\Courses\AI & Cybersecurity\Project\DriftAnalysis\visual.py:734: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[x,y].set_xticklabels(ax[x,y].get_xticks(), rotation=-90)
#
# 2024-12-01 17:45:28,210 - py.warnings - WARNING - c:\Users\Anthony\OneDrive - University of Luxembourg\Courses\AI & Cybersecurity\Project\DriftAnalysis\visual.py:734: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[x,y].set_xticklabels(ax[x,y].get_xticks(), rotation=-90)
#
# 2024-12-01 17:45:28,223 - py.warnings - WARNING - c:\Users\Anthony\OneDrive - University of Luxembourg\Courses\AI & Cybersecurity\Project\DriftAnalysis\visual.py:734: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[x,y].set_xticklabels(ax[x,y].get_xticks(), rotation=-90)
#
# 2024-12-01 17:45:28,235 - py.warnings - WARNING - c:\Users\Anthony\OneDrive - University of Luxembourg\Courses\AI & Cybersecurity\Project\DriftAnalysis\visual.py:734: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[x,y].set_xticklabels(ax[x,y].get_xticks(), rotation=-90)
#
# [84.0, 1.12, 93.7, 0.97, 1.99, 97.87]
# [54.13, 98.72, 41.06, 16.55, 1.99, 96.22]
# [61.24, 1.17, 36.78, 18.99, 7.14, 96.77]
# [2.92, 0.16, 2.96, 51.41, 3.04, 97.33]
# [0.06, 0.0, 0.0, 11.3, 100.0, 99.64]
# results\solo_performance_grid.pdf
# 2024-12-01 17:45:49,756 - py.warnings - WARNING - c:\Users\Anthony\OneDrive - University of Luxembourg\Courses\AI & Cybersecurity\Project\DriftAnalysis\visual.py:62: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
#
# results\tsne_malware_overtime.pdf
# ----------
# Top 5 feature(s) for group 1 for family DNOTUA
# 0 app_permissions::name='com_android_launcher_permission_INSTALL_SHORTCUT' 0.736624853695837 0.21
# 1 intents::android_intent_action_PACKAGE_ADDED 0.6315758467844513 0.18
# 2 interesting_calls::Cipher(DES) 0.6302533140800187 0.18
# 3 api_permissions::android_permission_GET_ACCOUNTS 0.3012492213275739 0.09
# 4 intents::android_intent_category_LAUNCHER 0.1982035127627082 0.06
# ----------
# Top 5 feature(s) for group 52 for family DNOTUA
# 0 urls::https://www_googletagmanager_com 0.9286299509981879 0.45
# 1 api_calls::android/content/Context;->startService 0.8208590570119447 0.39
# 2 intents::android_intent_category_LAUNCHER 0.1930873318989938 0.09
# 3 api_permissions::android_permission_INTERNET 0.0003924054644168784 0.0
# 4 activities::Mustach 0.0 0.0
# ----------
# Top 5 feature(s) for group 31 for family DNOTUA
# 0 urls::https://www_googletagmanager_com 1.0287542347936516 0.48
# 1 api_calls::android/content/Context;->startService 0.950194578881728 0.44
# 2 intents::android_intent_category_LAUNCHER 0.11189752704862155 0.05
# 3 api_permissions::android_permission_INTERNET 3.910688945030216e-05 0.0
# 4 activities::Mustach 0.0 0.0
# ----------
# Top 5 feature(s) for group 25 for family DNOTUA
# 0 intents::android_intent_category_LAUNCHER 0.23348687458581516 1.0
# 1 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 0.0
# 2 activities::studentsapps_storywriting_com_WebViewTest 0.0 0.0
# 3 activities::tenses 0.0 0.0
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 0.0
# ----------
# Top 5 feature(s) for group 47 for family DNOTUA
# 0 urls::https://www_googletagmanager_com 0.9584393652640572 0.43
# 1 api_calls::android/content/Context;->startService 0.9369094435993005 0.42
# 2 intents::android_intent_category_LAUNCHER 0.13074026873046307 0.06
# 3 api_permissions::android_permission_INTERNET 0.06225252674064411 0.03
# 4 intents::android_intent_action_USER_PRESENT 0.03772408579791385 0.02
# ----------
# Top 5 feature(s) for group 33 for family DNOTUA
# 0 urls::https://www_googletagmanager_com 1.2855947879414618 0.59
# 1 api_calls::android/content/Context;->startService 0.6067026952466589 0.28
# 2 s_and_r::com_qihoo_util_QhJobService 0.010955036863686695 0.01
# 3 app_permissions::name='android_webkit_permission_PLUGIN' 0.009277500443319065 0.0
# 4 api_permissions::android_permission_INTERNET 0.00045604568875665504 0.0
# ----------
# Top 5 feature(s) for group 27 for family DNOTUA
# 0 urls::https://www_googletagmanager_com 0.2230718306713809 0.3
# 1 api_calls::android/content/Context;->startService 0.16507398593114417 0.22
# 2 intents::android_intent_category_LAUNCHER 0.15332557801825697 0.21
# 3 activities::com_qihoo_util_appupdate_AppUpdateActivity 0.09031006569664865 0.12
# 4 api_permissions::android_permission_INTERNET 2.318922720854845e-05 0.0
# ----------
# Top 5 feature(s) for group 36 for family DNOTUA
# 0 urls::https://www_googletagmanager_com 0.9884790242701927 0.49
# 1 api_calls::android/content/Context;->startService 0.9879799926640342 0.49
# 2 intents::android_intent_category_LAUNCHER 0.01671280423213517 0.01
# 3 api_permissions::android_permission_INTERNET 5.763798061053649e-05 0.0
# 4 activities::Mustach 0.0 0.0
# ----------
# Top 5 feature(s) for group 22 for family DNOTUA
# 0 intents::android_intent_action_PACKAGE_ADDED 0.25761065842019676 0.32
# 1 intents::android_intent_category_LAUNCHER 0.22348949498507215 0.28
# 2 urls::http://www_dummy_com 0.03134670327558861 0.04
# 3 urls::https://www_googletagmanager_com 0.021135429940701497 0.03
# 4 api_permissions::android_permission_INTERNET 9.531953188002262e-05 0.0
# ----------
# Top 5 feature(s) for group 17 for family DNOTUA
# 2024-12-01 17:46:06,227 - py.warnings - WARNING - c:\Users\Anthony\OneDrive - University of Luxembourg\Courses\AI & Cybersecurity\Project\DriftAnalysis\visual.py:543: RuntimeWarning: invalid value encountered in scalar divide
#   print(i, feature_names[sample], explanations[group-1][sample], round(explanations[group-1][sample]/total, 2) )
#
# 0 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 nan
# 1 interesting_calls::Cipher(Ljava/util/List) 0.0 nan
# 2 interesting_calls::Cipher(DES/ECB/NoPadding) 0.0 nan
# 3 activities::tenses 0.0 nan
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 nan
# ----------
# Top 5 feature(s) for group 53 for family DNOTUA
# 0 urls::https://www_googletagmanager_com 0.8845135790012317 0.5
# 1 api_calls::android/content/Context;->startService 0.8831239016749668 0.5
# 2 intents::android_intent_category_LAUNCHER 0.0007830910482979903 0.0
# 3 api_permissions::android_permission_INTERNET 0.0004482568866137626 0.0
# 4 activities::Mustach 0.0 0.0
# ----------
# Top 5 feature(s) for group 44 for family DNOTUA
# 0 urls::https://www_googletagmanager_com 1.175738383168007 0.47
# 1 api_calls::android/content/Context;->startService 0.5738746659284614 0.23
# 2 intents::android_intent_category_LAUNCHER 0.2300822897043595 0.09
# 3 intents::android_intent_action_USER_PRESENT 0.10000937650469535 0.04
# 4 intents::android_intent_action_PACKAGE_ADDED 0.0993814144583049 0.04
# ----------
# Top 5 feature(s) for group 37 for family DNOTUA
# 0 api_calls::android/content/Context;->startService 1.0001912621826674 0.5
# 1 urls::https://www_googletagmanager_com 1.0001336537430985 0.5
# 2 intents::android_intent_category_LAUNCHER 0.0012263268063161803 0.0
# 3 api_permissions::android_permission_INTERNET 3.275430809246416e-05 0.0
# 4 activities::Mustach 0.0 0.0
# ----------
# Top 5 feature(s) for group 1 for family KUGUO
# 0 intents::android_intent_action_USER_PRESENT 1.9999494727650204 0.38
# 1 intents::android_intent_action_PACKAGE_ADDED 1.2631516935689027 0.24
# 2 app_permissions::name='com_android_launcher_permission_INSTALL_SHORTCUT' 0.4603905335598981 0.09
# 3 intents::android_intent_action_CREATE_SHORTCUT 0.2629937002912208 0.05
# 4 intents::android_intent_category_LAUNCHER 0.1982035127627082 0.04
# ----------
# Top 5 feature(s) for group 52 for family KUGUO
# 0 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 nan
# 1 interesting_calls::Cipher(Ljava/util/List) 0.0 nan
# 2 interesting_calls::Cipher(DES/ECB/NoPadding) 0.0 nan
# 3 activities::tenses 0.0 nan
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 nan
# ----------
# Top 5 feature(s) for group 31 for family KUGUO
# 0 intents::android_intent_category_LAUNCHER 0.11189752704862155 1.0
# 1 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 0.0
# 2 activities::studentsapps_storywriting_com_WebViewTest 0.0 0.0
# 3 activities::tenses 0.0 0.0
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 0.0
# ----------
# Top 5 feature(s) for group 25 for family KUGUO
# 0 intents::android_intent_action_USER_PRESENT 1.000041449373804 0.38
# 1 activities::com_baidu_mobads_AppActivity 0.4161836838691025 0.16
# 2 app_permissions::name='com_android_launcher_permission_INSTALL_SHORTCUT' 0.3333908783523962 0.13
# 3 intents::android_intent_category_LAUNCHER 0.23348687458581516 0.09
# 4 s_and_r::com_qq_e_comm_DownloadService 0.00014887628101157538 0.0
# ----------
# Top 5 feature(s) for group 47 for family KUGUO
# 0 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 nan
# 1 interesting_calls::Cipher(Ljava/util/List) 0.0 nan
# 2 interesting_calls::Cipher(DES/ECB/NoPadding) 0.0 nan
# 3 activities::tenses 0.0 nan
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 nan
# ----------
# Top 5 feature(s) for group 33 for family KUGUO
# 0 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 nan
# 1 interesting_calls::Cipher(Ljava/util/List) 0.0 nan
# 2 interesting_calls::Cipher(DES/ECB/NoPadding) 0.0 nan
# 3 activities::tenses 0.0 nan
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 nan
# ----------
# Top 5 feature(s) for group 27 for family KUGUO
# 0 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 nan
# 1 interesting_calls::Cipher(Ljava/util/List) 0.0 nan
# 2 interesting_calls::Cipher(DES/ECB/NoPadding) 0.0 nan
# 3 activities::tenses 0.0 nan
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 nan
# ----------
# Top 5 feature(s) for group 36 for family KUGUO
# 0 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 nan
# 1 interesting_calls::Cipher(Ljava/util/List) 0.0 nan
# 2 interesting_calls::Cipher(DES/ECB/NoPadding) 0.0 nan
# 3 activities::tenses 0.0 nan
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 nan
# ----------
# Top 5 feature(s) for group 22 for family KUGUO
# 0 intents::android_intent_action_USER_PRESENT 1.9712724458348967 0.6
# 1 app_permissions::name='com_android_launcher_permission_INSTALL_SHORTCUT' 0.7115484453482943 0.22
# 2 intents::android_intent_category_LAUNCHER 0.22348949498507228 0.07
# 3 api_calls::android/media/AudioManager;->setSpeakerphoneOn 0.027475324641464835 0.01
# 4 intents::android_intent_action_PACKAGE_ADDED 0.018141595663394138 0.01
# ----------
# Top 5 feature(s) for group 17 for family KUGUO
# 0 intents::android_intent_action_USER_PRESENT 1.620971525766778 0.46
# 1 app_permissions::name='com_android_launcher_permission_INSTALL_SHORTCUT' 0.8489299755737154 0.24
# 2 intents::android_intent_action_PACKAGE_ADDED 0.2742376333342001 0.08
# 3 intents::android_intent_category_LAUNCHER 0.19261589430239034 0.05
# 4 intents::android_intent_action_CREATE_SHORTCUT 0.11167177400647064 0.03
# ----------
# Top 5 feature(s) for group 53 for family KUGUO
# 0 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 nan
# 1 interesting_calls::Cipher(Ljava/util/List) 0.0 nan
# 2 interesting_calls::Cipher(DES/ECB/NoPadding) 0.0 nan
# 3 activities::tenses 0.0 nan
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 nan
# ----------
# Top 5 feature(s) for group 44 for family KUGUO
# 0 intents::android_intent_action_USER_PRESENT 1.3334583533959379 0.24
# 1 intents::android_intent_action_PACKAGE_ADDED 1.3250855261107317 0.23
# 2 api_calls::android/content/Context;->startService 0.5465473008842489 0.1
# 3 interesting_calls::Cipher(DES) 0.3786964638972112 0.07
# 4 intents::android_intent_category_LAUNCHER 0.2300822897043595 0.04
# ----------
# Top 5 feature(s) for group 37 for family KUGUO
# 0 urls::https://play_google_com/store/apps/details?id=com_smartdev_wesupportmodi 0.0 nan
# 1 interesting_calls::Cipher(Ljava/util/List) 0.0 nan
# 2 interesting_calls::Cipher(DES/ECB/NoPadding) 0.0 nan
# 3 activities::tenses 0.0 nan
# 4 urls::https://docs_google_com/spreadsheet/formResponse?formkey=%s&ifq 0.0 nan
